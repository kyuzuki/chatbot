# %% [markdown]
# My conversation with the chatbot

# %%
# %run ./hw4.ipynb
interact()
# Out:
# Hi. Ask me about Lilo and Stitch!
# User >>> hi
# ELIZA:  Salutations
#
# User >>> hi
# ELIZA:  Hi
#
# User >>> how are you
# I'm fine
#
# User >>> who is lilo
# ELIZA:  Lilo Pelekai is one of the main characters, who lives with her older sister Nani
#
# User >>> who is pleakley
# ELIZA:  Agent Wendell Pleakley is Jumba's partner, and is an expert on Planet Earth
#
# User >>> what is experiment 131
# ELIZA: Experiment 131 is named Poik
#
# User >>> what is poik
# ELIZA:  Designed to slap you three times. After she did it, she will laugh until she slaps another person. Also her laugh is loud and sounds like "poikpoikpoikpoik"
#
# User >>> what does experiment 412 do
# ELIZA:  Seen in pod form in Stitch! The Movie. Designed to burn bagels. He was mentioned in "Link" when Reuben was searching the experiment database.
#
# User >>> what does jumba do
# ELIZA:  Jumba is an evil genius who created Stitch and his cousins
#
# User >>> what does phantasmo do
# ...
