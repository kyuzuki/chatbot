# %%
# %run ./hw4.ipynb

# %%
interact()
# Out:
# Hi. Ask me about Lilo and Stitch!
# User >>> who is stitch
# ...

# %%
interact()
# Out:
# Hi. Ask me about Lilo and Stitch!
# User >>> my favorite experiment is 626
# ELIZA: Here is what I know about experiment 626
# Name:  Stitch
# Experiment Number:  626
# ...

# %%
interact()
# Out:
# Hi. Ask me about Lilo and Stitch!
# User >>> how tall is lilo
# ELIZA:  Lilo is 3 feet 5 inches tall
#
# User >>> how tall is stitch
# ELIZA:  Stitch is around 3 feet tall
#
# User >>> how tall is nani
# ELIZA:  If Lilo is ~3.5 feet tall, Nani must be at least 8 feet tall when looking at them next to eachother.
#
# User >>> how tall is david
# ELIZA:  If Lilo is ~3.5 feet tall, David must be at least 9 feet tall when looking at them next to eachother.
#
# User >>> how tall is jumba
# ELIZA:  Jumba is shorter than Nani, but is probably around 7 feet tall
#
# User >>> how tall is pleakley
# ELIZA:  Pleakley is shorter than Jumba, so is probably around 6 feet tall with his antenna
#
# User >>> how tall is gantu
# ELIZA:  Gantu is around 20 feet tall
#
# User >>> where does nani live
# ELIZA: Sorry, I don't know where nani lives.
#
# User >>> where does stitch live
# ELIZA:  Stitch lives with Lilo and Nani in their house outside of Kokaua Town, Hawaii
#
# User >>> where does david live
# ...

# %% [markdown]
# Friend's Impressions:
# "I was impressed with the in-depth character descriptions. I also enjoyed learning about the heights of the characters because they were outrageous which made it funny. For a majority of my questions, I got a direct response that made sense. I think the idea of creating a program all about Lilo and Stitch was really unique and I've definitely gained trivia knowledge about the franchise!"
